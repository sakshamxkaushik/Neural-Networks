# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input/concrete-crack-images'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ../input/concrete-crack-images/images/crack-o-568.jpg
# ../input/concrete-crack-images/images/crack-o-389.jpg
# ../input/concrete-crack-images/images/crack-o-537.jpg
# ../input/concrete-crack-images/images/crack-o-457.jpg
# ../input/concrete-crack-images/images/crack-o-614.jpg
# ../input/concrete-crack-images/images/crack-o-90.jpg
# ../input/concrete-crack-images/images/crack-o-674.jpg
# ../input/concrete-crack-images/images/crack-o-170.jpg
# ../input/concrete-crack-images/images/crack-o-115.jpg
# ../input/concrete-crack-images/images/crack-o-480.jpg
# ../input/concrete-crack-images/images/crack-o-350.jpg
# ../input/concrete-crack-images/images/crack-o-390.jpg
# ../input/concrete-crack-images/images/crack-o-621.jpg
# ../input/concrete-crack-images/images/crack-o-500.jpg
# ../input/concrete-crack-images/images/crack-o-242.jpg
# ../input/concrete-crack-images/images/crack-o-159.jpg
# ../input/concrete-crack-images/images/crack-o-789.jpg
# ../input/concrete-crack-images/images/crack-o-67.jpg
# ../input/concrete-crack-images/images/crack-o-610.jpg
# ../input/concrete-crack-images/images/crack-o-670.jpg
# ../input/concrete-crack-images/images/crack-o-599.jpg
# ../input/concrete-crack-images/images/crack-o-505.jpg
# ../input/concrete-crack-images/images/crack-o-673.jpg
# ../input/concrete-crack-images/images/crack-o-527.jpg
# ../input/concrete-crack-images/images/crack-o-683.jpg
# ../input/concrete-crack-images/images/crack-o-416.jpg
# ../input/concrete-crack-images/images/crack-o-755.jpg
# ../input/concrete-crack-images/images/crack-o-48.jpg
# ../input/concrete-crack-images/images/crack-o-598.jpg
# ../input/concrete-crack-images/images/crack-o-247.jpg
# ../input/concrete-crack-images/images/crack-o-272.jpg
# ../input/concrete-crack-images/images/crack-o-404.jpg
# ../input/concrete-crack-images/images/crack-o-38.jpg
# ../input/concrete-crack-images/images/crack-o-266.jpg
# ../input/concrete-crack-images/images/crack-o-669.jpg
# ../input/concrete-crack-images/images/crack-o-324.jpg
# ../input/concrete-crack-images/images/crack-o-566.jpg
# ../input/concrete-crack-images/images/crack-o-241.jpg
# ../input/concrete-crack-images/images/crack-o-127.jpg
# ../input/concrete-crack-images/images/crack-o-595.jpg
# ../input/concrete-crack-images/images/crack-o-331.jpg
# ../input/concrete-crack-images/images/crack-o-234.jpg
# ../input/concrete-crack-images/images/crack-o-757.jpg
# ../input/concrete-crack-images/images/crack-o-142.jpg
# ../input/concrete-crack-images/images/crack-o-471.jpg
# ../input/concrete-crack-images/images/crack-o-638.jpg
# ../input/concrete-crack-images/images/crack-o-467.jpg
# ../input/concrete-crack-images/images/crack-o-246.jpg
# ../input/concrete-crack-images/images/crack-o-780.jpg
# ../input/concrete-crack-images/images/crack-o-315.jpg
# ../input/concrete-crack-images/images/crack-o-525.jpg
# ../input/concrete-crack-images/images/crack-o-375.jpg
# ../input/concrete-crack-images/images/crack-o-56.jpg
# ../input/concrete-crack-images/images/crack-o-419.jpg
# ../input/concrete-crack-images/images/crack-o-769.jpg
# ../input/concrete-crack-images/images/crack-o-111.jpg
# ../input/concrete-crack-images/images/crack-o-89.jpg
# ../input/concrete-crack-images/images/crack-o-32.jpg
# ../input/concrete-crack-images/images/crack-o-361.jpg
# ../input/concrete-crack-images/images/crack-o-290.jpg
# ../input/concrete-crack-images/images/crack-o-158.jpg
# ../input/concrete-crack-images/images/crack-o-427.jpg
# ../input/concrete-crack-images/images/crack-o-321.jpg
# ../input/concrete-crack-images/images/crack-o-695.jpg
# ../input/concrete-crack-images/images/crack-o-207.jpg
# ../input/concrete-crack-images/images/crack-o-409.jpg
# ../input/concrete-crack-images/images/crack-o-192.jpg
# ../input/concrete-crack-images/images/crack-o-579.jpg
# ../input/concrete-crack-images/images/crack-o-203.jpg
# ../input/concrete-crack-images/images/crack-o-359.jpg
# ../input/concrete-crack-images/images/crack-o-726.jpg
# ../input/concrete-crack-images/images/crack-o-711.jpg
# ../input/concrete-crack-images/images/crack-o-501.jpg
# ../input/concrete-crack-images/images/crack-o-372.jpg
# ../input/concrete-crack-images/images/crack-o-4.jpg
# ../input/concrete-crack-images/images/crack-o-468.jpg
# ../input/concrete-crack-images/images/crack-o-235.jpg
# ../input/concrete-crack-images/images/crack-o-314.jpg
# ../input/concrete-crack-images/images/crack-o-493.jpg
# ../input/concrete-crack-images/images/crack-o-426.jpg
# ../input/concrete-crack-images/images/crack-o-212.jpg
# ../input/concrete-crack-images/images/crack-o-381.jpg
# ../input/concrete-crack-images/images/crack-o-195.jpg
# ../input/concrete-crack-images/images/crack-o-169.jpg
# ../input/concrete-crack-images/images/crack-o-97.jpg
# ../input/concrete-crack-images/images/crack-o-138.jpg
# ../input/concrete-crack-images/images/crack-o-477.jpg
# ../input/concrete-crack-images/images/crack-o-756.jpg
# ../input/concrete-crack-images/images/crack-o-484.jpg
# ../input/concrete-crack-images/images/crack-o-206.jpg
# ../input/concrete-crack-images/images/crack-o-728.jpg
# ../input/concrete-crack-images/images/crack-o-236.jpg
# ../input/concrete-crack-images/images/crack-o-156.jpg
# ../input/concrete-crack-images/images/crack-o-37.jpg
# ../input/concrete-crack-images/images/crack-o-496.jpg
# ../input/concrete-crack-images/images/crack-o-721.jpg
# ../input/concrete-crack-images/images/crack-o-513.jpg
# ../input/concrete-crack-images/images/crack-o-95.jpg
# ../input/concrete-crack-images/images/crack-o-29.jpg
# ../input/concrete-crack-images/images/crack-o-777.jpg
# ../input/concrete-crack-images/images/crack-o-86.jpg
# ../input/concrete-crack-images/images/crack-o-133.jpg
# ../input/concrete-crack-images/images/crack-o-608.jpg
# ../input/concrete-crack-images/images/crack-o-178.jpg
# ../input/concrete-crack-images/images/crack-o-762.jpg
# ../input/concrete-crack-images/images/crack-o-781.jpg
# ../input/concrete-crack-images/images/crack-o-752.jpg
# ../input/concrete-crack-images/images/crack-o-436.jpg
# ../input/concrete-crack-images/images/crack-o-44.jpg
# ../input/concrete-crack-images/images/crack-o-486.jpg
# ../input/concrete-crack-images/images/crack-o-347.jpg
# ../input/concrete-crack-images/images/crack-o-731.jpg
# ../input/concrete-crack-images/images/crack-o-149.jpg
# ../input/concrete-crack-images/images/crack-o-713.jpg
# ../input/concrete-crack-images/images/crack-o-709.jpg
# ../input/concrete-crack-images/images/crack-o-582.jpg
# ../input/concrete-crack-images/images/crack-o-707.jpg
# ../input/concrete-crack-images/images/crack-o-328.jpg
# ../input/concrete-crack-images/images/crack-o-10.jpg
# ../input/concrete-crack-images/images/crack-o-590.jpg
# ../input/concrete-crack-images/images/crack-o-344.jpg
# ../input/concrete-crack-images/images/crack-o-791.jpg
# ../input/concrete-crack-images/images/crack-o-214.jpg
# ../input/concrete-crack-images/images/crack-o-191.jpg
# ../input/concrete-crack-images/images/crack-o-397.jpg
# ../input/concrete-crack-images/images/crack-o-73.jpg
# ../input/concrete-crack-images/images/crack-o-68.jpg
# ../input/concrete-crack-images/images/crack-o-557.jpg
# ../input/concrete-crack-images/images/crack-o-462.jpg
# ../input/concrete-crack-images/images/crack-o-572.jpg
# ../input/concrete-crack-images/images/crack-o-720.jpg
# ../input/concrete-crack-images/images/crack-o-338.jpg
# ../input/concrete-crack-images/images/crack-o-619.jpg
# ../input/concrete-crack-images/images/crack-o-279.jpg
# ../input/concrete-crack-images/images/crack-o-14.jpg
# ../input/concrete-crack-images/images/crack-o-799.jpg
# ../input/concrete-crack-images/images/crack-o-297.jpg
# ../input/concrete-crack-images/images/crack-o-288.jpg
# ../input/concrete-crack-images/images/crack-o-773.jpg
# ../input/concrete-crack-images/images/crack-o-230.jpg
# ../input/concrete-crack-images/images/crack-o-476.jpg
# ../input/concrete-crack-images/images/crack-o-101.jpg
# ../input/concrete-crack-images/images/crack-o-767.jpg
# ../input/concrete-crack-images/images/crack-o-278.jpg
# ../input/concrete-crack-images/images/crack-o-81.jpg
# ../input/concrete-crack-images/images/crack-o-794.jpg
# ../input/concrete-crack-images/images/crack-o-693.jpg
# ../input/concrete-crack-images/images/crack-o-639.jpg
# ../input/concrete-crack-images/images/crack-o-494.jpg
# ../input/concrete-crack-images/images/crack-o-346.jpg
# ../input/concrete-crack-images/images/crack-o-473.jpg
# ../input/concrete-crack-images/images/crack-o-172.jpg
# ../input/concrete-crack-images/images/crack-o-296.jpg
# ../input/concrete-crack-images/images/crack-o-185.jpg
# ../input/concrete-crack-images/images/crack-o-489.jpg
# ../input/concrete-crack-images/images/crack-o-665.jpg
# ../input/concrete-crack-images/images/crack-o-636.jpg
# ../input/concrete-crack-images/images/crack-o-708.jpg
# ../input/concrete-crack-images/images/crack-o-141.jpg
# ../input/concrete-crack-images/images/crack-o-744.jpg
# ../input/concrete-crack-images/images/crack-o-11.jpg
# ../input/concrete-crack-images/images/crack-o-754.jpg
# ../input/concrete-crack-images/images/crack-o-20.jpg
# ../input/concrete-crack-images/images/crack-o-113.jpg
# ../input/concrete-crack-images/images/crack-o-186.jpg
# ../input/concrete-crack-images/images/crack-o-657.jpg
# ../input/concrete-crack-images/images/crack-o-538.jpg
# ../input/concrete-crack-images/images/crack-o-237.jpg
# ../input/concrete-crack-images/images/crack-o-58.jpg
# ../input/concrete-crack-images/images/crack-o-227.jpg
# ../input/concrete-crack-images/images/crack-o-251.jpg
# ../input/concrete-crack-images/images/crack-o-41.jpg
# ../input/concrete-crack-images/images/crack-o-368.jpg
# ../input/concrete-crack-images/images/crack-o-463.jpg
# ../input/concrete-crack-images/images/crack-o-578.jpg
# ../input/concrete-crack-images/images/crack-o-507.jpg
# ../input/concrete-crack-images/images/crack-o-403.jpg
# ../input/concrete-crack-images/images/crack-o-112.jpg
# ../input/concrete-crack-images/images/crack-o-542.jpg
# ../input/concrete-crack-images/images/crack-o-585.jpg
# ../input/concrete-crack-images/images/crack-o-727.jpg
# ../input/concrete-crack-images/images/crack-o-575.jpg
# ../input/concrete-crack-images/images/crack-o-378.jpg
# ../input/concrete-crack-images/images/crack-o-733.jpg
# ../input/concrete-crack-images/images/crack-o-132.jpg
# ../input/concrete-crack-images/images/crack-o-586.jpg
# ../input/concrete-crack-images/images/crack-o-282.jpg
# ../input/concrete-crack-images/images/crack-o-17.jpg
# ../input/concrete-crack-images/images/crack-o-105.jpg
# ../input/concrete-crack-images/images/crack-o-121.jpg
# ../input/concrete-crack-images/images/crack-o-569.jpg
# ../input/concrete-crack-images/images/crack-o-34.jpg
# ../input/concrete-crack-images/images/crack-o-552.jpg
# ../input/concrete-crack-images/images/crack-o-785.jpg
# ../input/concrete-crack-images/images/crack-o-747.jpg
# ../input/concrete-crack-images/images/crack-o-663.jpg
# ../input/concrete-crack-images/images/crack-o-438.jpg
# ../input/concrete-crack-images/images/crack-o-418.jpg
# ../input/concrete-crack-images/images/crack-o-332.jpg
# ../input/concrete-crack-images/images/crack-o-23.jpg
# ../input/concrete-crack-images/images/crack-o-139.jpg
# ../input/concrete-crack-images/images/crack-o-300.jpg
# ../input/concrete-crack-images/images/crack-o-233.jpg
# ../input/concrete-crack-images/images/crack-o-100.jpg
# ../input/concrete-crack-images/images/crack-o-544.jpg
# ../input/concrete-crack-images/images/crack-o-412.jpg
# ../input/concrete-crack-images/images/crack-o-1.jpg
# ../input/concrete-crack-images/images/crack-o-374.jpg
# ../input/concrete-crack-images/images/crack-o-659.jpg
# ../input/concrete-crack-images/images/crack-o-739.jpg
# ../input/concrete-crack-images/images/crack-o-760.jpg
# ../input/concrete-crack-images/images/crack-o-36.jpg
# ../input/concrete-crack-images/images/crack-o-160.jpg
# ../input/concrete-crack-images/images/crack-o-482.jpg
# ../input/concrete-crack-images/images/crack-o-694.jpg
# ../input/concrete-crack-images/images/crack-o-532.jpg
# ../input/concrete-crack-images/images/crack-o-106.jpg
# ../input/concrete-crack-images/images/crack-o-447.jpg
# ../input/concrete-crack-images/images/crack-o-208.jpg
# ../input/concrete-crack-images/images/crack-o-551.jpg
# ../input/concrete-crack-images/images/crack-o-717.jpg
# ../input/concrete-crack-images/images/crack-o-28.jpg
# ../input/concrete-crack-images/images/crack-o-763.jpg
# ../input/concrete-crack-images/images/crack-o-392.jpg
# ../input/concrete-crack-images/images/crack-o-649.jpg
# ../input/concrete-crack-images/images/crack-o-75.jpg
# ../input/concrete-crack-images/images/crack-o-345.jpg
# ../input/concrete-crack-images/images/crack-o-643.jpg
# ../input/concrete-crack-images/images/crack-o-432.jpg
# ../input/concrete-crack-images/images/crack-o-559.jpg
# ../input/concrete-crack-images/images/crack-o-50.jpg
# ../input/concrete-crack-images/images/crack-o-128.jpg
# ../input/concrete-crack-images/images/crack-o-39.jpg
# ../input/concrete-crack-images/images/crack-o-223.jpg
# ../input/concrete-crack-images/images/crack-o-143.jpg
# ../input/concrete-crack-images/images/crack-o-173.jpg
# ../input/concrete-crack-images/images/crack-o-91.jpg
# ../input/concrete-crack-images/images/crack-o-69.jpg
# ../input/concrete-crack-images/images/crack-o-618.jpg
# ../input/concrete-crack-images/images/crack-o-307.jpg
# ../input/concrete-crack-images/images/crack-o-571.jpg
# ../input/concrete-crack-images/images/crack-o-217.jpg
# ../input/concrete-crack-images/images/crack-o-215.jpg
# ../input/concrete-crack-images/images/crack-o-766.jpg
# ../input/concrete-crack-images/images/crack-o-775.jpg
# ../input/concrete-crack-images/images/crack-o-295.jpg
# ../input/concrete-crack-images/images/crack-o-648.jpg
# ../input/concrete-crack-images/images/crack-o-168.jpg
# ../input/concrete-crack-images/images/crack-o-715.jpg
# ../input/concrete-crack-images/images/crack-o-565.jpg
# ../input/concrete-crack-images/images/crack-o-753.jpg
# ../input/concrete-crack-images/images/crack-o-16.jpg
# ../input/concrete-crack-images/images/crack-o-12.jpg
# ../input/concrete-crack-images/images/crack-o-442.jpg
# ../input/concrete-crack-images/images/crack-o-129.jpg
# ../input/concrete-crack-images/images/crack-o-302.jpg
# ../input/concrete-crack-images/images/crack-o-252.jpg
# ../input/concrete-crack-images/images/crack-o-640.jpg
# ../input/concrete-crack-images/images/crack-o-413.jpg
# ../input/concrete-crack-images/images/crack-o-518.jpg
# ../input/concrete-crack-images/images/crack-o-164.jpg
# ../input/concrete-crack-images/images/crack-o-122.jpg
# ../input/concrete-crack-images/images/crack-o-417.jpg
# ../input/concrete-crack-images/images/crack-o-174.jpg
# ../input/concrete-crack-images/images/crack-o-646.jpg
# ../input/concrete-crack-images/images/crack-o-146.jpg
# ../input/concrete-crack-images/images/crack-o-704.jpg
# ../input/concrete-crack-images/images/crack-o-594.jpg
# ../input/concrete-crack-images/images/crack-o-453.jpg
# ../input/concrete-crack-images/images/crack-o-117.jpg
# ../input/concrete-crack-images/images/crack-o-445.jpg
# ../input/concrete-crack-images/images/crack-o-318.jpg
# ../input/concrete-crack-images/images/crack-o-93.jpg
# ../input/concrete-crack-images/images/crack-o-488.jpg
# ../input/concrete-crack-images/images/crack-o-277.jpg
# ../input/concrete-crack-images/images/crack-o-461.jpg
# ../input/concrete-crack-images/images/crack-o-748.jpg
# ../input/concrete-crack-images/images/crack-o-497.jpg
# ../input/concrete-crack-images/images/crack-o-465.jpg
# ../input/concrete-crack-images/images/crack-o-491.jpg
# ../input/concrete-crack-images/images/crack-o-740.jpg
# ../input/concrete-crack-images/images/crack-o-317.jpg
# ../input/concrete-crack-images/images/crack-o-616.jpg
# ../input/concrete-crack-images/images/crack-o-678.jpg
# ../input/concrete-crack-images/images/crack-o-239.jpg
# ../input/concrete-crack-images/images/crack-o-343.jpg
# ../input/concrete-crack-images/images/crack-o-679.jpg
# ../input/concrete-crack-images/images/crack-o-664.jpg
# ../input/concrete-crack-images/images/crack-o-216.jpg
# ../input/concrete-crack-images/images/crack-o-161.jpg
# ../input/concrete-crack-images/images/crack-o-298.jpg
# ../input/concrete-crack-images/images/crack-o-682.jpg
# ../input/concrete-crack-images/images/crack-o-286.jpg
# ../input/concrete-crack-images/images/crack-o-13.jpg
# ../input/concrete-crack-images/images/crack-o-784.jpg
# ../input/concrete-crack-images/images/crack-o-262.jpg
# ../input/concrete-crack-images/images/crack-o-260.jpg
# ../input/concrete-crack-images/images/crack-o-485.jpg
# ../input/concrete-crack-images/images/crack-o-124.jpg
# ../input/concrete-crack-images/images/crack-o-211.jpg
# ../input/concrete-crack-images/images/crack-o-615.jpg
# ../input/concrete-crack-images/images/crack-o-523.jpg
# ../input/concrete-crack-images/images/crack-o-8.jpg
# ../input/concrete-crack-images/images/crack-o-655.jpg
# ../input/concrete-crack-images/images/crack-o-77.jpg
# ../input/concrete-crack-images/images/crack-o-163.jpg
# ../input/concrete-crack-images/images/crack-o-265.jpg
# ../input/concrete-crack-images/images/crack-o-522.jpg
# ../input/concrete-crack-images/images/crack-o-719.jpg
# ../input/concrete-crack-images/images/crack-o-749.jpg
# ../input/concrete-crack-images/images/crack-o-583.jpg
# ../input/concrete-crack-images/images/crack-o-514.jpg
# ../input/concrete-crack-images/images/crack-o-581.jpg
# ../input/concrete-crack-images/images/crack-o-30.jpg
# ../input/concrete-crack-images/images/crack-o-451.jpg
# ../input/concrete-crack-images/images/crack-o-220.jpg
# ../input/concrete-crack-images/images/crack-o-228.jpg
# ../input/concrete-crack-images/images/crack-o-376.jpg
# ../input/concrete-crack-images/images/crack-o-231.jpg
# ../input/concrete-crack-images/images/crack-o-716.jpg
# ../input/concrete-crack-images/images/crack-o-261.jpg
# ../input/concrete-crack-images/images/crack-o-357.jpg
# ../input/concrete-crack-images/images/crack-o-393.jpg
# ../input/concrete-crack-images/images/crack-o-289.jpg
# ../input/concrete-crack-images/images/crack-o-560.jpg
# ../input/concrete-crack-images/images/crack-o-554.jpg
# ../input/concrete-crack-images/images/crack-o-661.jpg
# ../input/concrete-crack-images/images/crack-o-396.jpg
# ../input/concrete-crack-images/images/crack-o-725.jpg
# ../input/concrete-crack-images/images/crack-o-238.jpg
# ../input/concrete-crack-images/images/crack-o-503.jpg
# ../input/concrete-crack-images/images/crack-o-779.jpg
# ../input/concrete-crack-images/images/crack-o-152.jpg
# ../input/concrete-crack-images/images/crack-o-76.jpg
# ../input/concrete-crack-images/images/crack-o-273.jpg
# ../input/concrete-crack-images/images/crack-o-601.jpg
# ../input/concrete-crack-images/images/crack-o-516.jpg
# ../input/concrete-crack-images/images/crack-o-367.jpg
# ../input/concrete-crack-images/images/crack-o-330.jpg
# ../input/concrete-crack-images/images/crack-o-729.jpg
# ../input/concrete-crack-images/images/crack-o-351.jpg
# ../input/concrete-crack-images/images/crack-o-140.jpg
# ../input/concrete-crack-images/images/crack-o-222.jpg
# ../input/concrete-crack-images/images/crack-o-177.jpg
# ../input/concrete-crack-images/images/crack-o-517.jpg
# ../input/concrete-crack-images/images/crack-o-714.jpg
# ../input/concrete-crack-images/images/crack-o-319.jpg
# ../input/concrete-crack-images/images/crack-o-31.jpg
# ../input/concrete-crack-images/images/crack-o-102.jpg
# ../input/concrete-crack-images/images/crack-o-487.jpg
# ../input/concrete-crack-images/images/crack-o-99.jpg
# ../input/concrete-crack-images/images/crack-o-656.jpg
# ../input/concrete-crack-images/images/crack-o-402.jpg
# ../input/concrete-crack-images/images/crack-o-795.jpg
# ../input/concrete-crack-images/images/crack-o-555.jpg
# ../input/concrete-crack-images/images/crack-o-604.jpg
# ../input/concrete-crack-images/images/crack-o-509.jpg
# ../input/concrete-crack-images/images/crack-o-199.jpg
# ../input/concrete-crack-images/images/crack-o-210.jpg
# ../input/concrete-crack-images/images/crack-o-741.jpg
# ../input/concrete-crack-images/images/crack-o-654.jpg
# ../input/concrete-crack-images/images/crack-o-398.jpg
# ../input/concrete-crack-images/images/crack-o-742.jpg
# ../input/concrete-crack-images/images/crack-o-362.jpg
# ../input/concrete-crack-images/images/crack-o-736.jpg
# ../input/concrete-crack-images/images/crack-o-653.jpg
# ../input/concrete-crack-images/images/crack-o-281.jpg
# ../input/concrete-crack-images/images/crack-o-710.jpg
# ../input/concrete-crack-images/images/crack-o-190.jpg
# ../input/concrete-crack-images/images/crack-o-83.jpg
# ../input/concrete-crack-images/images/crack-o-737.jpg
# ../input/concrete-crack-images/images/crack-o-150.jpg
# ../input/concrete-crack-images/images/crack-o-611.jpg
# ../input/concrete-crack-images/images/crack-o-520.jpg
# ../input/concrete-crack-images/images/crack-o-205.jpg
# ../input/concrete-crack-images/images/crack-o-213.jpg
# ../input/concrete-crack-images/images/crack-o-270.jpg
# ../input/concrete-crack-images/images/crack-o-219.jpg
# ../input/concrete-crack-images/images/crack-o-363.jpg
# ../input/concrete-crack-images/images/crack-o-576.jpg
# ../input/concrete-crack-images/images/crack-o-408.jpg
# ../input/concrete-crack-images/images/crack-o-257.jpg
# ../input/concrete-crack-images/images/crack-o-3.jpg
# ../input/concrete-crack-images/images/crack-o-606.jpg
# ../input/concrete-crack-images/images/crack-o-108.jpg
# ../input/concrete-crack-images/images/crack-o-103.jpg
# ../input/concrete-crack-images/images/crack-o-684.jpg
# ../input/concrete-crack-images/images/crack-o-641.jpg
# ../input/concrete-crack-images/images/crack-o-366.jpg
# ../input/concrete-crack-images/images/crack-o-6.jpg
# ../input/concrete-crack-images/images/crack-o-510.jpg
# ../input/concrete-crack-images/images/crack-o-793.jpg
# ../input/concrete-crack-images/images/crack-o-702.jpg
# ../input/concrete-crack-images/images/crack-o-448.jpg
# ../input/concrete-crack-images/images/crack-o-197.jpg
# ../input/concrete-crack-images/images/crack-o-478.jpg
# ../input/concrete-crack-images/images/crack-o-248.jpg
# ../input/concrete-crack-images/images/crack-o-74.jpg
# ../input/concrete-crack-images/images/crack-o-84.jpg
# ../input/concrete-crack-images/images/crack-o-658.jpg
# ../input/concrete-crack-images/images/crack-o-61.jpg
# ../input/concrete-crack-images/images/crack-o-626.jpg
# ../input/concrete-crack-images/images/crack-o-243.jpg
# ../input/concrete-crack-images/images/crack-o-722.jpg
# ../input/concrete-crack-images/images/crack-o-703.jpg
# ../input/concrete-crack-images/images/crack-o-506.jpg
# ../input/concrete-crack-images/images/crack-o-182.jpg
# ../input/concrete-crack-images/images/crack-o-274.jpg
# ../input/concrete-crack-images/images/crack-o-183.jpg
# ../input/concrete-crack-images/images/crack-o-336.jpg
# ../input/concrete-crack-images/images/crack-o-570.jpg
# ../input/concrete-crack-images/images/crack-o-384.jpg
# ../input/concrete-crack-images/images/crack-o-577.jpg
# ../input/concrete-crack-images/images/crack-o-492.jpg
# ../input/concrete-crack-images/images/crack-o-642.jpg
# ../input/concrete-crack-images/images/crack-o-562.jpg
# ../input/concrete-crack-images/images/crack-o-310.jpg
# ../input/concrete-crack-images/images/crack-o-697.jpg
# ../input/concrete-crack-images/images/crack-o-369.jpg
# ../input/concrete-crack-images/images/crack-o-681.jpg
# ../input/concrete-crack-images/images/crack-o-224.jpg
# ../input/concrete-crack-images/images/crack-o-364.jpg
# ../input/concrete-crack-images/images/crack-o-786.jpg
# ../input/concrete-crack-images/images/crack-o-600.jpg
# ../input/concrete-crack-images/images/crack-o-751.jpg
# ../input/concrete-crack-images/images/crack-o-240.jpg
# ../input/concrete-crack-images/images/crack-o-40.jpg
# ../input/concrete-crack-images/images/crack-o-64.jpg
# ../input/concrete-crack-images/images/crack-o-2.jpg
# ../input/concrete-crack-images/images/crack-o-543.jpg
# ../input/concrete-crack-images/images/crack-o-180.jpg
# ../input/concrete-crack-images/images/crack-o-483.jpg
# ../input/concrete-crack-images/images/crack-o-422.jpg
# ../input/concrete-crack-images/images/crack-o-617.jpg
# ../input/concrete-crack-images/images/crack-o-573.jpg
# ../input/concrete-crack-images/images/crack-o-386.jpg
# ../input/concrete-crack-images/images/crack-o-759.jpg
# ../input/concrete-crack-images/images/crack-o-80.jpg
# ../input/concrete-crack-images/images/crack-o-264.jpg
# ../input/concrete-crack-images/images/crack-o-299.jpg
# ../input/concrete-crack-images/images/crack-o-284.jpg
# ../input/concrete-crack-images/images/crack-o-685.jpg
# ../input/concrete-crack-images/images/crack-o-254.jpg
# ../input/concrete-crack-images/images/crack-o-79.jpg
# ../input/concrete-crack-images/images/crack-o-699.jpg
# ../input/concrete-crack-images/images/crack-o-46.jpg
# ../input/concrete-crack-images/images/crack-o-519.jpg
# ../input/concrete-crack-images/images/crack-o-116.jpg
# ../input/concrete-crack-images/images/crack-o-675.jpg
# ../input/concrete-crack-images/images/crack-o-125.jpg
# ../input/concrete-crack-images/images/crack-o-267.jpg
# ../input/concrete-crack-images/images/crack-o-428.jpg
# ../input/concrete-crack-images/images/crack-o-449.jpg
# ../input/concrete-crack-images/images/crack-o-800.jpg
# ../input/concrete-crack-images/images/crack-o-624.jpg
# ../input/concrete-crack-images/images/crack-o-743.jpg
# ../input/concrete-crack-images/images/crack-o-200.jpg
# ../input/concrete-crack-images/images/crack-o-798.jpg
# ../input/concrete-crack-images/images/crack-o-337.jpg
# ../input/concrete-crack-images/images/crack-o-47.jpg
# ../input/concrete-crack-images/images/crack-o-607.jpg
# ../input/concrete-crack-images/images/crack-o-605.jpg
# ../input/concrete-crack-images/images/crack-o-253.jpg
# ../input/concrete-crack-images/images/crack-o-24.jpg
# ../input/concrete-crack-images/images/crack-o-305.jpg
# ../input/concrete-crack-images/images/crack-o-580.jpg
# ../input/concrete-crack-images/images/crack-o-271.jpg
# ../input/concrete-crack-images/images/crack-o-25.jpg
# ../input/concrete-crack-images/images/crack-o-788.jpg
# ../input/concrete-crack-images/images/crack-o-72.jpg
# ../input/concrete-crack-images/images/crack-o-460.jpg
# ../input/concrete-crack-images/images/crack-o-424.jpg
# ../input/concrete-crack-images/images/crack-o-790.jpg
# ../input/concrete-crack-images/images/crack-o-63.jpg
# ../input/concrete-crack-images/images/crack-o-7.jpg
# ../input/concrete-crack-images/images/crack-o-244.jpg
# ../input/concrete-crack-images/images/crack-o-311.jpg
# ../input/concrete-crack-images/images/crack-o-193.jpg
# ../input/concrete-crack-images/images/crack-o-771.jpg
# ../input/concrete-crack-images/images/crack-o-764.jpg
# ../input/concrete-crack-images/images/crack-o-602.jpg
# ../input/concrete-crack-images/images/crack-o-26.jpg
# ../input/concrete-crack-images/images/crack-o-118.jpg
# ../input/concrete-crack-images/images/crack-o-291.jpg
# ../input/concrete-crack-images/images/crack-o-429.jpg
# ../input/concrete-crack-images/images/crack-o-43.jpg
# ../input/concrete-crack-images/images/crack-o-688.jpg
# ../input/concrete-crack-images/images/crack-o-772.jpg
# ../input/concrete-crack-images/images/crack-o-630.jpg
# ../input/concrete-crack-images/images/crack-o-269.jpg
# ../input/concrete-crack-images/images/crack-o-70.jpg
# ../input/concrete-crack-images/images/crack-o-62.jpg
# ../input/concrete-crack-images/images/crack-o-405.jpg
# ../input/concrete-crack-images/images/crack-o-245.jpg
# ../input/concrete-crack-images/images/crack-o-687.jpg
# ../input/concrete-crack-images/images/crack-o-671.jpg
# ../input/concrete-crack-images/images/crack-o-54.jpg
# ../input/concrete-crack-images/images/crack-o-768.jpg
# ../input/concrete-crack-images/images/crack-o-189.jpg
# ../input/concrete-crack-images/images/crack-o-541.jpg
# ../input/concrete-crack-images/images/crack-o-529.jpg
# ../input/concrete-crack-images/images/crack-o-745.jpg
# ../input/concrete-crack-images/images/crack-o-723.jpg
# ../input/concrete-crack-images/images/crack-o-15.jpg
# ../input/concrete-crack-images/images/crack-o-706.jpg
# ../input/concrete-crack-images/images/crack-o-689.jpg
# ../input/concrete-crack-images/images/crack-o-155.jpg
# ../input/concrete-crack-images/images/crack-o-797.jpg
# ../input/concrete-crack-images/images/crack-o-667.jpg
# ../input/concrete-crack-images/images/crack-o-651.jpg
# ../input/concrete-crack-images/images/crack-o-157.jpg
# ../input/concrete-crack-images/images/crack-o-750.jpg
# ../input/concrete-crack-images/images/crack-o-340.jpg
# ../input/concrete-crack-images/images/crack-o-738.jpg
# ../input/concrete-crack-images/images/crack-o-546.jpg
# ../input/concrete-crack-images/images/crack-o-770.jpg
# ../input/concrete-crack-images/images/crack-o-628.jpg
# ../input/concrete-crack-images/images/crack-o-258.jpg
# ../input/concrete-crack-images/images/crack-o-365.jpg
# ../input/concrete-crack-images/images/crack-o-691.jpg
# ../input/concrete-crack-images/images/crack-o-796.jpg
# ../input/concrete-crack-images/images/crack-o-761.jpg
# ../input/concrete-crack-images/images/crack-o-609.jpg
# ../input/concrete-crack-images/images/crack-o-452.jpg
# ../input/concrete-crack-images/images/crack-o-229.jpg
# ../input/concrete-crack-images/images/crack-o-51.jpg
# ../input/concrete-crack-images/images/crack-o-329.jpg
# ../input/concrete-crack-images/images/crack-o-533.jpg
# ../input/concrete-crack-images/images/crack-o-635.jpg
# ../input/concrete-crack-images/images/crack-o-285.jpg
# ../input/concrete-crack-images/images/crack-o-627.jpg
# ../input/concrete-crack-images/images/crack-o-134.jpg
# ../input/concrete-crack-images/images/crack-o-443.jpg
# ../input/concrete-crack-images/images/crack-o-110.jpg
# ../input/concrete-crack-images/images/crack-o-201.jpg
# ../input/concrete-crack-images/images/crack-o-433.jpg
# ../input/concrete-crack-images/images/crack-o-104.jpg
# ../input/concrete-crack-images/images/crack-o-263.jpg
# ../input/concrete-crack-images/images/crack-o-423.jpg
# ../input/concrete-crack-images/images/crack-o-335.jpg
# ../input/concrete-crack-images/images/crack-o-194.jpg
# ../input/concrete-crack-images/images/crack-o-184.jpg
# ../input/concrete-crack-images/images/crack-o-530.jpg
# ../input/concrete-crack-images/images/crack-o-232.jpg
# ../input/concrete-crack-images/images/crack-o-539.jpg
# ../input/concrete-crack-images/images/crack-o-78.jpg
# ../input/concrete-crack-images/images/crack-o-425.jpg
# ../input/concrete-crack-images/images/crack-o-458.jpg
# ../input/concrete-crack-images/images/crack-o-550.jpg
# ../input/concrete-crack-images/images/crack-o-593.jpg
# ../input/concrete-crack-images/images/crack-o-144.jpg
# ../input/concrete-crack-images/images/crack-o-401.jpg
# ../input/concrete-crack-images/images/crack-o-596.jpg
# ../input/concrete-crack-images/images/crack-o-391.jpg
# ../input/concrete-crack-images/images/crack-o-130.jpg
# ../input/concrete-crack-images/images/crack-o-558.jpg
# ../input/concrete-crack-images/images/crack-o-45.jpg
# ../input/concrete-crack-images/images/crack-o-250.jpg
# ../input/concrete-crack-images/images/crack-o-446.jpg
# ../input/concrete-crack-images/images/crack-o-87.jpg
# ../input/concrete-crack-images/images/crack-o-613.jpg
# ../input/concrete-crack-images/images/crack-o-293.jpg
# ../input/concrete-crack-images/images/crack-o-275.jpg
# ../input/concrete-crack-images/images/crack-o-276.jpg
# ../input/concrete-crack-images/images/crack-o-735.jpg
# ../input/concrete-crack-images/images/crack-o-60.jpg
# ../input/concrete-crack-images/images/crack-o-620.jpg
# ../input/concrete-crack-images/images/crack-o-355.jpg
# ../input/concrete-crack-images/images/crack-o-209.jpg
# ../input/concrete-crack-images/images/crack-o-410.jpg
# ../input/concrete-crack-images/images/crack-o-179.jpg
# ../input/concrete-crack-images/images/crack-o-531.jpg
# ../input/concrete-crack-images/images/crack-o-746.jpg
# ../input/concrete-crack-images/images/crack-o-421.jpg
# ../input/concrete-crack-images/images/crack-o-515.jpg
# ../input/concrete-crack-images/images/crack-o-662.jpg
# ../input/concrete-crack-images/images/crack-o-705.jpg
# ../input/concrete-crack-images/images/crack-o-734.jpg
# ../input/concrete-crack-images/images/crack-o-339.jpg
# ../input/concrete-crack-images/images/crack-o-547.jpg
# ../input/concrete-crack-images/images/crack-o-637.jpg
# ../input/concrete-crack-images/images/crack-o-512.jpg
# ../input/concrete-crack-images/images/crack-o-181.jpg
# ../input/concrete-crack-images/images/crack-o-783.jpg
# ../input/concrete-crack-images/images/crack-o-123.jpg
# ../input/concrete-crack-images/images/crack-o-490.jpg
# ../input/concrete-crack-images/images/crack-o-145.jpg
# ../input/concrete-crack-images/images/crack-o-668.jpg
# ../input/concrete-crack-images/images/crack-o-470.jpg
# ../input/concrete-crack-images/images/crack-o-765.jpg
# ../input/concrete-crack-images/images/crack-o-782.jpg
# ../input/concrete-crack-images/images/crack-o-303.jpg
# ../input/concrete-crack-images/images/crack-o-535.jpg
# ../input/concrete-crack-images/images/crack-o-348.jpg
# ../input/concrete-crack-images/images/crack-o-165.jpg
# ../input/concrete-crack-images/images/crack-o-395.jpg
# ../input/concrete-crack-images/images/crack-o-65.jpg
# ../input/concrete-crack-images/images/crack-o-5.jpg
# ../input/concrete-crack-images/images/crack-o-502.jpg
# ../input/concrete-crack-images/images/crack-o-135.jpg
# ../input/concrete-crack-images/images/crack-o-166.jpg
# ../input/concrete-crack-images/images/crack-o-672.jpg
# ../input/concrete-crack-images/images/crack-o-52.jpg
# ../input/concrete-crack-images/images/crack-o-511.jpg
# ../input/concrete-crack-images/images/crack-o-584.jpg
# ../input/concrete-crack-images/images/crack-o-652.jpg
# ../input/concrete-crack-images/images/crack-o-352.jpg
# ../input/concrete-crack-images/images/crack-o-66.jpg
# ../input/concrete-crack-images/images/crack-o-327.jpg
# ../input/concrete-crack-images/images/crack-o-358.jpg
# ../input/concrete-crack-images/images/crack-o-437.jpg
# ../input/concrete-crack-images/images/crack-o-371.jpg
# ../input/concrete-crack-images/images/crack-o-633.jpg
# ../input/concrete-crack-images/images/crack-o-387.jpg
# ../input/concrete-crack-images/images/crack-o-85.jpg
# ../input/concrete-crack-images/images/crack-o-187.jpg
# ../input/concrete-crack-images/images/crack-o-632.jpg
# ../input/concrete-crack-images/images/crack-o-151.jpg
# ../input/concrete-crack-images/images/crack-o-495.jpg
# ../input/concrete-crack-images/images/crack-o-221.jpg
# ../input/concrete-crack-images/images/crack-o-349.jpg
# ../input/concrete-crack-images/images/crack-o-724.jpg
# ../input/concrete-crack-images/images/crack-o-313.jpg
# ../input/concrete-crack-images/images/crack-o-325.jpg
# ../input/concrete-crack-images/images/crack-o-385.jpg
# ../input/concrete-crack-images/images/crack-o-9.jpg
# ../input/concrete-crack-images/images/crack-o-431.jpg
# ../input/concrete-crack-images/images/crack-o-35.jpg
# ../input/concrete-crack-images/images/crack-o-175.jpg
# ../input/concrete-crack-images/images/crack-o-259.jpg
# ../input/concrete-crack-images/images/crack-o-466.jpg
# ../input/concrete-crack-images/images/crack-o-21.jpg
# ../input/concrete-crack-images/images/crack-o-55.jpg
# ../input/concrete-crack-images/images/crack-o-623.jpg
# ../input/concrete-crack-images/images/crack-o-758.jpg
# ../input/concrete-crack-images/images/crack-o-49.jpg
# ../input/concrete-crack-images/images/crack-o-154.jpg
# ../input/concrete-crack-images/images/crack-o-677.jpg
# ../input/concrete-crack-images/images/crack-o-114.jpg
# ../input/concrete-crack-images/images/crack-o-57.jpg
# ../input/concrete-crack-images/images/crack-o-563.jpg
# ../input/concrete-crack-images/images/crack-o-411.jpg
# ../input/concrete-crack-images/images/crack-o-27.jpg
# ../input/concrete-crack-images/images/crack-o-153.jpg
# ../input/concrete-crack-images/images/crack-o-309.jpg
# ../input/concrete-crack-images/images/crack-o-96.jpg
# ../input/concrete-crack-images/images/crack-o-162.jpg
# ../input/concrete-crack-images/images/crack-o-690.jpg
# ../input/concrete-crack-images/images/crack-o-455.jpg
# ../input/concrete-crack-images/images/crack-o-730.jpg
# ../input/concrete-crack-images/images/crack-o-137.jpg
# ../input/concrete-crack-images/images/crack-o-373.jpg
# ../input/concrete-crack-images/images/crack-o-92.jpg
# ../input/concrete-crack-images/images/crack-o-561.jpg
# ../input/concrete-crack-images/images/crack-o-249.jpg
# ../input/concrete-crack-images/images/crack-o-167.jpg
# ../input/concrete-crack-images/images/crack-o-475.jpg
# ../input/concrete-crack-images/images/crack-o-479.jpg
# ../input/concrete-crack-images/images/crack-o-308.jpg
# ../input/concrete-crack-images/images/crack-o-59.jpg
# ../input/concrete-crack-images/images/crack-o-534.jpg
# ../input/concrete-crack-images/images/crack-o-549.jpg
# ../input/concrete-crack-images/images/crack-o-456.jpg
# ../input/concrete-crack-images/images/crack-o-312.jpg
# ../input/concrete-crack-images/images/crack-o-474.jpg
# ../input/concrete-crack-images/images/crack-o-120.jpg
# ../input/concrete-crack-images/images/crack-o-94.jpg
# ../input/concrete-crack-images/images/crack-o-407.jpg
# ../input/concrete-crack-images/images/crack-o-292.jpg
# ../input/concrete-crack-images/images/crack-o-287.jpg
# ../input/concrete-crack-images/images/crack-o-136.jpg
# ../input/concrete-crack-images/images/crack-o-322.jpg
# ../input/concrete-crack-images/images/crack-o-354.jpg
# ../input/concrete-crack-images/images/crack-o-268.jpg
# ../input/concrete-crack-images/images/crack-o-383.jpg
# ../input/concrete-crack-images/images/crack-o-188.jpg
# ../input/concrete-crack-images/images/crack-o-588.jpg
# ../input/concrete-crack-images/images/crack-o-316.jpg
# ../input/concrete-crack-images/images/crack-o-304.jpg
# ../input/concrete-crack-images/images/crack-o-198.jpg
# ../input/concrete-crack-images/images/crack-o-430.jpg
# ../input/concrete-crack-images/images/crack-o-334.jpg
# ../input/concrete-crack-images/images/crack-o-400.jpg
# ../input/concrete-crack-images/images/crack-o-171.jpg
# ../input/concrete-crack-images/images/crack-o-306.jpg
# ../input/concrete-crack-images/images/crack-o-380.jpg
# ../input/concrete-crack-images/images/crack-o-444.jpg
# ../input/concrete-crack-images/images/crack-o-712.jpg
# ../input/concrete-crack-images/images/crack-o-464.jpg
# ../input/concrete-crack-images/images/crack-o-394.jpg
# ../input/concrete-crack-images/images/crack-o-504.jpg
# ../input/concrete-crack-images/images/crack-o-147.jpg
# ../input/concrete-crack-images/images/crack-o-406.jpg
# ../input/concrete-crack-images/images/crack-o-19.jpg
# ../input/concrete-crack-images/images/crack-o-696.jpg
# ../input/concrete-crack-images/images/crack-o-774.jpg
# ../input/concrete-crack-images/images/crack-o-353.jpg
# ../input/concrete-crack-images/images/crack-o-333.jpg
# ../input/concrete-crack-images/images/crack-o-528.jpg
# ../input/concrete-crack-images/images/crack-o-450.jpg
# ../input/concrete-crack-images/images/crack-o-414.jpg
# ../input/concrete-crack-images/images/crack-o-370.jpg
# ../input/concrete-crack-images/images/crack-o-107.jpg
# ../input/concrete-crack-images/images/crack-o-176.jpg
# ../input/concrete-crack-images/images/crack-o-326.jpg
# ../input/concrete-crack-images/images/crack-o-320.jpg
# ../input/concrete-crack-images/images/crack-o-42.jpg
# ../input/concrete-crack-images/images/crack-o-629.jpg
# ../input/concrete-crack-images/images/crack-o-82.jpg
# ../input/concrete-crack-images/images/crack-o-589.jpg
# ../input/concrete-crack-images/images/crack-o-545.jpg
# ../input/concrete-crack-images/images/crack-o-567.jpg
# ../input/concrete-crack-images/images/crack-o-131.jpg
# ../input/concrete-crack-images/images/crack-o-508.jpg
# ../input/concrete-crack-images/images/crack-o-440.jpg
# ../input/concrete-crack-images/images/crack-o-341.jpg
# ../input/concrete-crack-images/images/crack-o-415.jpg
# ../input/concrete-crack-images/images/crack-o-587.jpg
# ../input/concrete-crack-images/images/crack-o-294.jpg
# ../input/concrete-crack-images/images/crack-o-524.jpg
# ../input/concrete-crack-images/images/crack-o-420.jpg
# ../input/concrete-crack-images/images/crack-o-666.jpg
# ../input/concrete-crack-images/images/crack-o-644.jpg
# ../input/concrete-crack-images/images/crack-o-701.jpg
# ../input/concrete-crack-images/images/crack-o-591.jpg
# ../input/concrete-crack-images/images/crack-o-202.jpg
# ../input/concrete-crack-images/images/crack-o-660.jpg
# ../input/concrete-crack-images/images/crack-o-645.jpg
# ../input/concrete-crack-images/images/crack-o-787.jpg
# ../input/concrete-crack-images/images/crack-o-776.jpg
# ../input/concrete-crack-images/images/crack-o-225.jpg
# ../input/concrete-crack-images/images/crack-o-356.jpg
# ../input/concrete-crack-images/images/crack-o-625.jpg
# ../input/concrete-crack-images/images/crack-o-218.jpg
# ../input/concrete-crack-images/images/crack-o-283.jpg
# ../input/concrete-crack-images/images/crack-o-498.jpg
# ../input/concrete-crack-images/images/crack-o-564.jpg
# ../input/concrete-crack-images/images/crack-o-280.jpg
# ../input/concrete-crack-images/images/crack-o-435.jpg
# ../input/concrete-crack-images/images/crack-o-603.jpg
# ../input/concrete-crack-images/images/crack-o-647.jpg
# ../input/concrete-crack-images/images/crack-o-148.jpg
# ../input/concrete-crack-images/images/crack-o-698.jpg
# ../input/concrete-crack-images/images/crack-o-597.jpg
# ../input/concrete-crack-images/images/crack-o-399.jpg
# ../input/concrete-crack-images/images/crack-o-382.jpg
# ../input/concrete-crack-images/images/crack-o-126.jpg
# ../input/concrete-crack-images/images/crack-o-686.jpg
# ../input/concrete-crack-images/images/crack-o-540.jpg
# ../input/concrete-crack-images/images/crack-o-109.jpg
# ../input/concrete-crack-images/images/crack-o-778.jpg
# ../input/concrete-crack-images/images/crack-o-33.jpg
# ../input/concrete-crack-images/images/crack-o-22.jpg
# ../input/concrete-crack-images/images/crack-o-556.jpg
# ../input/concrete-crack-images/images/crack-o-196.jpg
# ../input/concrete-crack-images/images/crack-o-718.jpg
# ../input/concrete-crack-images/images/crack-o-388.jpg
# ../input/concrete-crack-images/images/crack-o-612.jpg
# ../input/concrete-crack-images/images/crack-o-792.jpg
# ../input/concrete-crack-images/images/crack-o-301.jpg
# ../input/concrete-crack-images/images/crack-o-256.jpg
# ../input/concrete-crack-images/images/crack-o-521.jpg
# ../input/concrete-crack-images/images/crack-o-18.jpg
# ../input/concrete-crack-images/images/crack-o-499.jpg
# ../input/concrete-crack-images/images/crack-o-574.jpg
# ../input/concrete-crack-images/images/crack-o-680.jpg
# ../input/concrete-crack-images/images/crack-o-469.jpg
# ../input/concrete-crack-images/images/crack-o-700.jpg
# ../input/concrete-crack-images/images/crack-o-377.jpg
# ../input/concrete-crack-images/images/crack-o-360.jpg
# ../input/concrete-crack-images/images/crack-o-592.jpg
# ../input/concrete-crack-images/images/crack-o-53.jpg
# ../input/concrete-crack-images/images/crack-o-434.jpg
# ../input/concrete-crack-images/images/crack-o-553.jpg
# ../input/concrete-crack-images/images/crack-o-634.jpg
# ../input/concrete-crack-images/images/crack-o-119.jpg
# ../input/concrete-crack-images/images/crack-o-631.jpg
# ../input/concrete-crack-images/images/crack-o-454.jpg
# ../input/concrete-crack-images/images/crack-o-472.jpg
# ../input/concrete-crack-images/images/crack-o-732.jpg
# ../input/concrete-crack-images/images/crack-o-459.jpg
# ../input/concrete-crack-images/images/crack-o-650.jpg
# ../input/concrete-crack-images/images/crack-o-255.jpg
# ../input/concrete-crack-images/images/crack-o-676.jpg
# ../input/concrete-crack-images/images/crack-o-622.jpg
# ../input/concrete-crack-images/images/crack-o-88.jpg
# ../input/concrete-crack-images/images/crack-o-379.jpg
# ../input/concrete-crack-images/images/crack-o-323.jpg
# ../input/concrete-crack-images/images/crack-o-536.jpg
# ../input/concrete-crack-images/images/crack-o-692.jpg
# ../input/concrete-crack-images/images/crack-o-481.jpg
# ../input/concrete-crack-images/images/crack-o-441.jpg
# ../input/concrete-crack-images/images/crack-o-71.jpg
# ../input/concrete-crack-images/images/crack-o-342.jpg
# ../input/concrete-crack-images/images/crack-o-439.jpg
# ../input/concrete-crack-images/images/crack-o-526.jpg
# ../input/concrete-crack-images/images/crack-o-98.jpg
# ../input/concrete-crack-images/images/crack-o-548.jpg
# ../input/concrete-crack-images/images/crack-o-226.jpg
# ../input/concrete-crack-images/images/crack-o-204.jpg
# ../input/concrete-crack-images/masks/crack-o-498.png
# ../input/concrete-crack-images/masks/crack-o-382.png
# ../input/concrete-crack-images/masks/crack-o-6.png
# ../input/concrete-crack-images/masks/crack-o-723.png
# ../input/concrete-crack-images/masks/crack-o-799.png
# ../input/concrete-crack-images/masks/crack-o-14.png
# ../input/concrete-crack-images/masks/crack-o-181.png
# ../input/concrete-crack-images/masks/crack-o-643.png
# ../input/concrete-crack-images/masks/crack-o-198.png
# ../input/concrete-crack-images/masks/crack-o-299.png
# ../input/concrete-crack-images/masks/crack-o-600.png
# ../input/concrete-crack-images/masks/crack-o-371.png
# ../input/concrete-crack-images/masks/crack-o-484.png
# ../input/concrete-crack-images/masks/crack-o-328.png
# ../input/concrete-crack-images/masks/crack-o-66.png
# ../input/concrete-crack-images/masks/crack-o-798.png
# ../input/concrete-crack-images/masks/crack-o-257.png
# ../input/concrete-crack-images/masks/crack-o-671.png
# ../input/concrete-crack-images/masks/crack-o-91.png
# ../input/concrete-crack-images/masks/crack-o-132.png
# ../input/concrete-crack-images/masks/crack-o-220.png
# ../input/concrete-crack-images/masks/crack-o-533.png
# ../input/concrete-crack-images/masks/crack-o-651.png
# ../input/concrete-crack-images/masks/crack-o-243.png
# ../input/concrete-crack-images/masks/crack-o-482.png
# ../input/concrete-crack-images/masks/crack-o-184.png
# ../input/concrete-crack-images/masks/crack-o-557.png
# ../input/concrete-crack-images/masks/crack-o-611.png
# ../input/concrete-crack-images/masks/crack-o-165.png
# ../input/concrete-crack-images/masks/crack-o-318.png
# ../input/concrete-crack-images/masks/crack-o-790.png
# ../input/concrete-crack-images/masks/crack-o-667.png
# ../input/concrete-crack-images/masks/crack-o-781.png
# ../input/concrete-crack-images/masks/crack-o-269.png
# ../input/concrete-crack-images/masks/crack-o-357.png
# ../input/concrete-crack-images/masks/crack-o-27.png
# ../input/concrete-crack-images/masks/crack-o-399.png
# ../input/concrete-crack-images/masks/crack-o-129.png
# ../input/concrete-crack-images/masks/crack-o-68.png
# ../input/concrete-crack-images/masks/crack-o-278.png
# ../input/concrete-crack-images/masks/crack-o-64.png
# ../input/concrete-crack-images/masks/crack-o-659.png
# ../input/concrete-crack-images/masks/crack-o-192.png
# ../input/concrete-crack-images/masks/crack-o-589.png
# ../input/concrete-crack-images/masks/crack-o-532.png
# ../input/concrete-crack-images/masks/crack-o-96.png
# ../input/concrete-crack-images/masks/crack-o-75.png
# ../input/concrete-crack-images/masks/crack-o-767.png
# ../input/concrete-crack-images/masks/crack-o-666.png
# ../input/concrete-crack-images/masks/crack-o-366.png
# ../input/concrete-crack-images/masks/crack-o-346.png
# ../input/concrete-crack-images/masks/crack-o-515.png
# ../input/concrete-crack-images/masks/crack-o-258.png
# ../input/concrete-crack-images/masks/crack-o-727.png
# ../input/concrete-crack-images/masks/crack-o-654.png
# ../input/concrete-crack-images/masks/crack-o-475.png
# ../input/concrete-crack-images/masks/crack-o-53.png
# ../input/concrete-crack-images/masks/crack-o-67.png
# ../input/concrete-crack-images/masks/crack-o-735.png
# ../input/concrete-crack-images/masks/crack-o-427.png
# ../input/concrete-crack-images/masks/crack-o-581.png
# ../input/concrete-crack-images/masks/crack-o-534.png
# ../input/concrete-crack-images/masks/crack-o-430.png
# ../input/concrete-crack-images/masks/crack-o-763.png
# ../input/concrete-crack-images/masks/crack-o-1.png
# ../input/concrete-crack-images/masks/crack-o-795.png
# ../input/concrete-crack-images/masks/crack-o-225.png
# ../input/concrete-crack-images/masks/crack-o-260.png
# ../input/concrete-crack-images/masks/crack-o-467.png
# ../input/concrete-crack-images/masks/crack-o-640.png
# ../input/concrete-crack-images/masks/crack-o-395.png
# ../input/concrete-crack-images/masks/crack-o-358.png
# ../input/concrete-crack-images/masks/crack-o-755.png
# ../input/concrete-crack-images/masks/crack-o-545.png
# ../input/concrete-crack-images/masks/crack-o-13.png
# ../input/concrete-crack-images/masks/crack-o-97.png
# ../input/concrete-crack-images/masks/crack-o-595.png
# ../input/concrete-crack-images/masks/crack-o-746.png
# ../input/concrete-crack-images/masks/crack-o-687.png
# ../input/concrete-crack-images/masks/crack-o-250.png
# ../input/concrete-crack-images/masks/crack-o-729.png
# ../input/concrete-crack-images/masks/crack-o-569.png
# ../input/concrete-crack-images/masks/crack-o-641.png
# ../input/concrete-crack-images/masks/crack-o-444.png
# ../input/concrete-crack-images/masks/crack-o-306.png
# ../input/concrete-crack-images/masks/crack-o-34.png
# ../input/concrete-crack-images/masks/crack-o-426.png
# ../input/concrete-crack-images/masks/crack-o-307.png
# ../input/concrete-crack-images/masks/crack-o-726.png
# ../input/concrete-crack-images/masks/crack-o-424.png
# ../input/concrete-crack-images/masks/crack-o-80.png
# ../input/concrete-crack-images/masks/crack-o-682.png
# ...
# ../input/concrete-crack-images/masks/crack-o-662.png
# ../input/concrete-crack-images/masks/crack-o-219.png
# ../input/concrete-crack-images/masks/crack-o-711.png
# ../input/concrete-crack-images/masks/crack-o-16.png
# ../input/concrete-crack-images/masks/crack-o-112.png
# ../input/concrete-crack-images/masks/crack-o-163.png
# ../input/concrete-crack-images/masks/crack-o-164.png
# ../input/concrete-crack-images/masks/crack-o-26.png
# ../input/concrete-crack-images/masks/crack-o-234.png
# ../input/concrete-crack-images/masks/crack-o-409.png
# ../input/concrete-crack-images/masks/crack-o-88.png
# ../input/concrete-crack-images/masks/crack-o-182.png
# ../input/concrete-crack-images/masks/crack-o-238.png
# ../input/concrete-crack-images/masks/crack-o-276.png
# ../input/concrete-crack-images/masks/crack-o-349.png
# ../input/concrete-crack-images/masks/crack-o-773.png
# ../input/concrete-crack-images/masks/crack-o-588.png
# ../input/concrete-crack-images/masks/crack-o-57.png
# ../input/concrete-crack-images/masks/crack-o-127.png
# ../input/concrete-crack-images/masks/crack-o-717.png
# ../input/concrete-crack-images/masks/crack-o-215.png
# ../input/concrete-crack-images/masks/crack-o-465.png
# ../input/concrete-crack-images/masks/crack-o-356.png
# ../input/concrete-crack-images/masks/crack-o-674.png
# ../input/concrete-crack-images/masks/crack-o-331.png
# ../input/concrete-crack-images/masks/crack-o-147.png
# ../input/concrete-crack-images/masks/crack-o-615.png
# ../input/concrete-crack-images/masks/crack-o-383.png
# ../input/concrete-crack-images/masks/crack-o-139.png
# ../input/concrete-crack-images/masks/crack-o-422.png
# ../input/concrete-crack-images/masks/crack-o-453.png
# ../input/concrete-crack-images/masks/crack-o-24.png
# ../input/concrete-crack-images/masks/crack-o-448.png
# ../input/concrete-crack-images/masks/crack-o-586.png
# ../input/concrete-crack-images/masks/crack-o-377.png
# ../input/concrete-crack-images/masks/crack-o-298.png
# ../input/concrete-crack-images/masks/crack-o-86.png
# ../input/concrete-crack-images/masks/crack-o-477.png
# ../input/concrete-crack-images/masks/crack-o-141.png
# ../input/concrete-crack-images/masks/crack-o-235.png
# ../input/concrete-crack-images/masks/crack-o-265.png
# ../input/concrete-crack-images/masks/crack-o-635.png
# ../input/concrete-crack-images/masks/crack-o-46.png
# ../input/concrete-crack-images/masks/crack-o-227.png
# ../input/concrete-crack-images/masks/crack-o-652.png
# ../input/concrete-crack-images/masks/crack-o-458.png
# ../input/concrete-crack-images/masks/crack-o-575.png
# ../input/concrete-crack-images/masks/crack-o-742.png
# ../input/concrete-crack-images/masks/crack-o-739.png
# ../input/concrete-crack-images/masks/crack-o-155.png
# ../input/concrete-crack-images/masks/crack-o-206.png
# ../input/concrete-crack-images/masks/crack-o-415.png
# ../input/concrete-crack-images/masks/crack-o-607.png
# ../input/concrete-crack-images/masks/crack-o-179.png
# ../input/concrete-crack-images/masks/crack-o-365.png
# ../input/concrete-crack-images/masks/crack-o-302.png
# ../input/concrete-crack-images/masks/crack-o-442.png
# ../input/concrete-crack-images/masks/crack-o-738.png
# ../input/concrete-crack-images/masks/crack-o-270.png
# ../input/concrete-crack-images/masks/crack-o-157.png
# ../input/concrete-crack-images/masks/crack-o-736.png
# ../input/concrete-crack-images/masks/crack-o-559.png
# ../input/concrete-crack-images/masks/crack-o-440.png
# ../input/concrete-crack-images/masks/crack-o-457.png
# ../input/concrete-crack-images/masks/crack-o-254.png
# ../input/concrete-crack-images/masks/crack-o-36.png
# ../input/concrete-crack-images/masks/crack-o-60.png
# ../input/concrete-crack-images/masks/crack-o-732.png
# ../input/concrete-crack-images/masks/crack-o-115.png
# ../input/concrete-crack-images/masks/crack-o-590.png
# ../input/concrete-crack-images/masks/crack-o-779.png
# ../input/concrete-crack-images/masks/crack-o-560.png
# ../input/concrete-crack-images/masks/crack-o-602.png
# ../input/concrete-crack-images/masks/crack-o-431.png
# ../input/concrete-crack-images/masks/crack-o-625.png
# ../input/concrete-crack-images/masks/crack-o-126.png
# ../input/concrete-crack-images/masks/crack-o-552.png
# ../input/concrete-crack-images/masks/crack-o-644.png
# ../input/concrete-crack-images/masks/crack-o-108.png
# ../input/concrete-crack-images/masks/crack-o-555.png
# ../input/concrete-crack-images/masks/crack-o-425.png
# ../input/concrete-crack-images/masks/crack-o-626.png
# ../input/concrete-crack-images/masks/crack-o-42.png
# ../input/concrete-crack-images/masks/crack-o-119.png
# ../input/concrete-crack-images/masks/crack-o-226.png
# ../input/concrete-crack-images/masks/crack-o-622.png
# ../input/concrete-crack-images/masks/crack-o-473.png
# ../input/concrete-crack-images/masks/crack-o-499.png
# ../input/concrete-crack-images/masks/crack-o-247.png
# ../input/concrete-crack-images/masks/crack-o-751.png
# ../input/concrete-crack-images/masks/crack-o-704.png
# ../input/concrete-crack-images/masks/crack-o-51.png
# ../input/concrete-crack-images/masks/crack-o-242.png
# ../input/concrete-crack-images/masks/crack-o-561.png
# ../input/concrete-crack-images/masks/crack-o-631.png
# ../input/concrete-crack-images/masks/crack-o-320.png
# ../input/concrete-crack-images/masks/crack-o-660.png
# ../input/concrete-crack-images/masks/crack-o-95.png
# ../input/concrete-crack-images/masks/crack-o-769.png
# ../input/concrete-crack-images/masks/crack-o-449.png
# ../input/concrete-crack-images/masks/crack-o-517.png
# ../input/concrete-crack-images/masks/crack-o-138.png
# ../input/concrete-crack-images/masks/crack-o-369.png
# ../input/concrete-crack-images/masks/crack-o-542.png
# ../input/concrete-crack-images/masks/crack-o-391.png
# ../input/concrete-crack-images/masks/crack-o-724.png
# ../input/concrete-crack-images/masks/crack-o-398.png
# ../input/concrete-crack-images/masks/crack-o-79.png
# ../input/concrete-crack-images/masks/crack-o-393.png
# ../input/concrete-crack-images/masks/crack-o-28.png
# ../input/concrete-crack-images/masks/crack-o-678.png
# ../input/concrete-crack-images/masks/crack-o-439.png
# ../input/concrete-crack-images/masks/crack-o-462.png
# ../input/concrete-crack-images/masks/crack-o-148.png
# ../input/concrete-crack-images/masks/crack-o-152.png
# ../input/concrete-crack-images/masks/crack-o-323.png
# ../input/concrete-crack-images/masks/crack-o-495.png
# ../input/concrete-crack-images/masks/crack-o-617.png
# ../input/concrete-crack-images/masks/crack-o-176.png
# ../input/concrete-crack-images/masks/crack-o-71.png
# ../input/concrete-crack-images/masks/crack-o-38.png
# ../input/concrete-crack-images/masks/crack-o-673.png
# ../input/concrete-crack-images/masks/crack-o-120.png
# ../input/concrete-crack-images/masks/crack-o-213.png
# ../input/concrete-crack-images/masks/crack-o-211.png
# ../input/concrete-crack-images/masks/crack-o-221.png
# ../input/concrete-crack-images/masks/crack-o-137.png
# ../input/concrete-crack-images/masks/crack-o-702.png
# ../input/concrete-crack-images/masks/crack-o-229.png
# ../input/concrete-crack-images/masks/crack-o-443.png
# ../input/concrete-crack-images/masks/crack-o-433.png
# ../input/concrete-crack-images/masks/crack-o-523.png
# ../input/concrete-crack-images/masks/crack-o-770.png
# ../input/concrete-crack-images/masks/crack-o-77.png
# ../input/concrete-crack-images/masks/crack-o-340.png
# ../input/concrete-crack-images/masks/crack-o-413.png
# ../input/concrete-crack-images/masks/crack-o-347.png
# ../input/concrete-crack-images/masks/crack-o-639.png
# ../input/concrete-crack-images/masks/crack-o-85.png
# ../input/concrete-crack-images/masks/crack-o-9.png
# ../input/concrete-crack-images/masks/crack-o-169.png
# ../input/concrete-crack-images/masks/crack-o-48.png
# ../input/concrete-crack-images/masks/crack-o-794.png
# ../input/concrete-crack-images/masks/crack-o-633.png
# ../input/concrete-crack-images/masks/crack-o-558.png
# ../input/concrete-crack-images/masks/crack-o-494.png
# ../input/concrete-crack-images/masks/crack-o-288.png
# ../input/concrete-crack-images/masks/crack-o-259.png
# ../input/concrete-crack-images/masks/crack-o-580.png
# ../input/concrete-crack-images/masks/crack-o-40.png
# ../input/concrete-crack-images/masks/crack-o-628.png
# ../input/concrete-crack-images/masks/crack-o-350.png
# ../input/concrete-crack-images/masks/crack-o-381.png
# ../input/concrete-crack-images/masks/crack-o-170.png
# ../input/concrete-crack-images/masks/crack-o-605.png
# ../input/concrete-crack-images/masks/crack-o-464.png
# ../input/concrete-crack-images/masks/crack-o-684.png
# ../input/concrete-crack-images/masks/crack-o-210.png
# ../input/concrete-crack-images/masks/crack-o-222.png
# ../input/concrete-crack-images/masks/crack-o-370.png
# ../input/concrete-crack-images/masks/crack-o-512.png
# ../input/concrete-crack-images/masks/crack-o-105.png
# ../input/concrete-crack-images/masks/crack-o-778.png
# ../input/concrete-crack-images/masks/crack-o-656.png
# ../input/concrete-crack-images/masks/crack-o-403.png
# ../input/concrete-crack-images/masks/crack-o-216.png
# ../input/concrete-crack-images/masks/crack-o-314.png
# ../input/concrete-crack-images/masks/crack-o-311.png
# ../input/concrete-crack-images/masks/crack-o-441.png
# ../input/concrete-crack-images/masks/crack-o-657.png
# ../input/concrete-crack-images/masks/crack-o-8.png
# ../input/concrete-crack-images/masks/crack-o-764.png
# ../input/concrete-crack-images/masks/crack-o-272.png
# ../input/concrete-crack-images/masks/crack-o-39.png
# ../input/concrete-crack-images/masks/crack-o-511.png
# ../input/concrete-crack-images/masks/crack-o-390.png
# ../input/concrete-crack-images/masks/crack-o-5.png
# ../input/concrete-crack-images/masks/crack-o-35.png
# ../input/concrete-crack-images/masks/crack-o-208.png
# ../input/concrete-crack-images/masks/crack-o-800.png
# ../input/concrete-crack-images/masks/crack-o-733.png
# ../input/concrete-crack-images/masks/crack-o-691.png
# ../input/concrete-crack-images/masks/crack-o-326.png
# ../input/concrete-crack-images/masks/crack-o-232.png
# ../input/concrete-crack-images/masks/crack-o-578.png
# ../input/concrete-crack-images/masks/crack-o-744.png
# ../input/concrete-crack-images/masks/crack-o-200.png
# ../input/concrete-crack-images/masks/crack-o-74.png
# ../input/concrete-crack-images/masks/crack-o-618.png
# ../input/concrete-crack-images/masks/crack-o-417.png
# ../input/concrete-crack-images/masks/crack-o-263.png
# ../input/concrete-crack-images/masks/crack-o-562.png
# ../input/concrete-crack-images/masks/crack-o-538.png
# ../input/concrete-crack-images/masks/crack-o-785.png
# ../input/concrete-crack-images/masks/crack-o-514.png
# ../input/concrete-crack-images/masks/crack-o-601.png
# ../input/concrete-crack-images/masks/crack-o-531.png
# ../input/concrete-crack-images/masks/crack-o-180.png
# ../input/concrete-crack-images/masks/crack-o-197.png
# ../input/concrete-crack-images/masks/crack-o-703.png
# ../input/concrete-crack-images/masks/crack-o-195.png
# ../input/concrete-crack-images/masks/crack-o-55.png
# ../input/concrete-crack-images/masks/crack-o-536.png
# ../input/concrete-crack-images/masks/crack-o-240.png
# ../input/concrete-crack-images/masks/crack-o-537.png
# ../input/concrete-crack-images/masks/crack-o-594.png
# ../input/concrete-crack-images/masks/crack-o-201.png
# ../input/concrete-crack-images/masks/crack-o-149.png
# ../input/concrete-crack-images/masks/crack-o-231.png
# ../input/concrete-crack-images/masks/crack-o-362.png
# ../input/concrete-crack-images/masks/crack-o-368.png
# ../input/concrete-crack-images/masks/crack-o-150.png
# ../input/concrete-crack-images/masks/crack-o-420.png
# ../input/concrete-crack-images/masks/crack-o-782.png
# ../input/concrete-crack-images/masks/crack-o-496.png
# ../input/concrete-crack-images/masks/crack-o-193.png
# ../input/concrete-crack-images/masks/crack-o-675.png
# ../input/concrete-crack-images/masks/crack-o-553.png
# ../input/concrete-crack-images/masks/crack-o-599.png
# ../input/concrete-crack-images/masks/crack-o-519.png
# ../input/concrete-crack-images/masks/crack-o-274.png
# ../input/concrete-crack-images/masks/crack-o-669.png
# ../input/concrete-crack-images/masks/crack-o-692.png
# ../input/concrete-crack-images/masks/crack-o-402.png
# ../input/concrete-crack-images/masks/crack-o-411.png
# ../input/concrete-crack-images/masks/crack-o-131.png
# ../input/concrete-crack-images/masks/crack-o-463.png
# ../input/concrete-crack-images/masks/crack-o-737.png
# ../input/concrete-crack-images/masks/crack-o-4.png
# ../input/concrete-crack-images/masks/crack-o-159.png
# ../input/concrete-crack-images/masks/crack-o-638.png
# ../input/concrete-crack-images/masks/crack-o-454.png
# ../input/concrete-crack-images/masks/crack-o-452.png
# ../input/concrete-crack-images/masks/crack-o-285.png
# ../input/concrete-crack-images/masks/crack-o-106.png
# ../input/concrete-crack-images/masks/crack-o-355.png
# ../input/concrete-crack-images/masks/crack-o-646.png
# ../input/concrete-crack-images/masks/crack-o-548.png
# ../input/concrete-crack-images/masks/crack-o-768.png
# ../input/concrete-crack-images/masks/crack-o-488.png
# ../input/concrete-crack-images/masks/crack-o-608.png
# ../input/concrete-crack-images/masks/crack-o-63.png
# ../input/concrete-crack-images/masks/crack-o-376.png
# ../input/concrete-crack-images/masks/crack-o-313.png
# ../input/concrete-crack-images/masks/crack-o-592.png
# ../input/concrete-crack-images/masks/crack-o-571.png
# ../input/concrete-crack-images/masks/crack-o-741.png
# ../input/concrete-crack-images/masks/crack-o-327.png
# ../input/concrete-crack-images/masks/crack-o-766.png
# ../input/concrete-crack-images/masks/crack-o-41.png
# ../input/concrete-crack-images/masks/crack-o-130.png
# ../input/concrete-crack-images/masks/crack-o-772.png
# ../input/concrete-crack-images/masks/crack-o-472.png
# ../input/concrete-crack-images/masks/crack-o-33.png
# ../input/concrete-crack-images/masks/crack-o-354.png
# ../input/concrete-crack-images/masks/crack-o-786.png
# ../input/concrete-crack-images/masks/crack-o-716.png
# ../input/concrete-crack-images/masks/crack-o-101.png
# ../input/concrete-crack-images/masks/crack-o-609.png
# ../input/concrete-crack-images/masks/crack-o-50.png
# ../input/concrete-crack-images/masks/crack-o-754.png
# ../input/concrete-crack-images/masks/crack-o-367.png
# ../input/concrete-crack-images/masks/crack-o-526.png
# ../input/concrete-crack-images/masks/crack-o-445.png
# ../input/concrete-crack-images/masks/crack-o-15.png
# ../input/concrete-crack-images/masks/crack-o-731.png
# ../input/concrete-crack-images/masks/crack-o-637.png
# ../input/concrete-crack-images/masks/crack-o-681.png
# ../input/concrete-crack-images/masks/crack-o-474.png
# ../input/concrete-crack-images/masks/crack-o-84.png
# ../input/concrete-crack-images/masks/crack-o-209.png
# ../input/concrete-crack-images/masks/crack-o-185.png
# ../input/concrete-crack-images/masks/crack-o-76.png
# ../input/concrete-crack-images/masks/crack-o-103.png
# ../input/concrete-crack-images/masks/crack-o-642.png
# ../input/concrete-crack-images/masks/crack-o-793.png
# ../input/concrete-crack-images/masks/crack-o-249.png
# ../input/concrete-crack-images/masks/crack-o-22.png
# ../input/concrete-crack-images/masks/crack-o-478.png
# ../input/concrete-crack-images/masks/crack-o-284.png
# ../input/concrete-crack-images/masks/crack-o-78.png
# ../input/concrete-crack-images/masks/crack-o-698.png
# ../input/concrete-crack-images/masks/crack-o-62.png
# ../input/concrete-crack-images/masks/crack-o-188.png
# ../input/concrete-crack-images/masks/crack-o-310.png
# ../input/concrete-crack-images/masks/crack-o-191.png
# ../input/concrete-crack-images/masks/crack-o-549.png
# ../input/concrete-crack-images/masks/crack-o-205.png
# ../input/concrete-crack-images/masks/crack-o-428.png
# ../input/concrete-crack-images/masks/crack-o-636.png
# ../input/concrete-crack-images/masks/crack-o-701.png
# ../input/concrete-crack-images/masks/crack-o-535.png
# ../input/concrete-crack-images/masks/crack-o-756.png
# ../input/concrete-crack-images/masks/crack-o-529.png
# ../input/concrete-crack-images/masks/crack-o-292.png
# ../input/concrete-crack-images/masks/crack-o-289.png
# ../input/concrete-crack-images/masks/crack-o-423.png
# ../input/concrete-crack-images/masks/crack-o-20.png
# ../input/concrete-crack-images/masks/crack-o-233.png
# ../input/concrete-crack-images/masks/crack-o-124.png
# ../input/concrete-crack-images/masks/crack-o-539.png
# ../input/concrete-crack-images/masks/crack-o-563.png

# %% [markdown]
# # U-Net Original Research Paper
# ### Paper Name: U-Net: Convolutional Networks for Biomedical Image Segmentation
# ### Paper Link: https://arxiv.org/pdf/1505.04597.pdf

# %% [markdown]
# # Configs

# %%
class ROOTDIR:
    train = "../input/concrete-crack-images/images"
    train_mask = "../input/concrete-crack-images/masks"

# %% [markdown]
# # General Imports

# %%
import os
import cv2
import zipfile
import numpy as np
import pandas as pd
from PIL import Image
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# # Extracting Files

# %% [markdown]
# dirs = ["../input/carvana-image-masking-challenge/train.zip",
#         "../input/carvana-image-masking-challenge/train_masks.zip",
#         "../input/carvana-image-masking-challenge/metadata.csv.zip"]
#
# for i in tqdm(dirs):
#     with zipfile.ZipFile(i) as z:
#         z.extractall()

# %% [markdown]
# # Working with CSV

# %%
#df = pd.read_csv("./metadata.csv")
#df.head()

# %%
#df.info()

# %% [markdown]
# # Working with Train Images and Masks

# %%
train_img_lst = os.listdir('../input/concrete-crack-images/images') # "./train"
train_mask_lst = os.listdir('../input/concrete-crack-images/masks') # "./train_masks"

# %%
print(train_mask_lst[:5])
print(train_img_lst[:5])
# Out:
# ['crack-o-498.png', 'crack-o-382.png', 'crack-o-6.png', 'crack-o-723.png', 'crack-o-799.png']
# ['crack-o-568.jpg', 'crack-o-389.jpg', 'crack-o-537.jpg', 'crack-o-457.jpg', 'crack-o-614.jpg']

# %%
print(len(train_mask_lst))
print(len(train_img_lst))
# Out:
# 800
# 800

# %% [markdown]
# #### Sorting to make sure we get right image and right mask

# %%
sorted_train_mask_lst = sorted(train_mask_lst)

# %%
sorted_train_img_lst = sorted(train_img_lst)

# %%
print(sorted_train_mask_lst[:16])
print(sorted_train_img_lst[:16])
# Out:
# ['crack-o-1.png', 'crack-o-10.png', 'crack-o-100.png', 'crack-o-101.png', 'crack-o-102.png', 'crack-o-103.png', 'crack-o-104.png', 'crack-o-105.png', 'crack-o-106.png', 'crack-o-107.png', 'crack-o-108.png', 'crack-o-109.png', 'crack-o-11.png', 'crack-o-110.png', 'crack-o-111.png', 'crack-o-112.png']
# ['crack-o-1.jpg', 'crack-o-10.jpg', 'crack-o-100.jpg', 'crack-o-101.jpg', 'crack-o-102.jpg', 'crack-o-103.jpg', 'crack-o-104.jpg', 'crack-o-105.jpg', 'crack-o-106.jpg', 'crack-o-107.jpg', 'crack-o-108.jpg', 'crack-o-109.jpg', 'crack-o-11.jpg', 'crack-o-110.jpg', 'crack-o-111.jpg', 'crack-o-112.jpg']

# %% [markdown]
# # Visualizing Images with their Mask
# ### Making sure images and mask are paired correctly.

# %%
def show_images(imgs_lst,masks_lst,loops=2):
    for i in range(loops):
        img_path = os.path.join(ROOTDIR.train,imgs_lst[i])
        mask_path = os.path.join(ROOTDIR.train_mask,masks_lst[i])
        img = Image.open(img_path)
        mask = Image.open(mask_path)
        print(img_path)
        print(img.size)
        print(type(img))
        plt.imshow(img)
        plt.show()
        print(mask_path)
        print(mask.size)
        plt.imshow(mask)
        plt.show()
        print("----------------------------------------------------")

show_images(sorted_train_img_lst, sorted_train_mask_lst)
# Out:
# ../input/concrete-crack-images/images/crack-o-1.jpg
# (256, 256)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# ../input/concrete-crack-images/masks/crack-o-1.png
# (256, 256)
# ----------------------------------------------------
# ../input/concrete-crack-images/images/crack-o-10.jpg
# (256, 256)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# ../input/concrete-crack-images/masks/crack-o-10.png
# (256, 256)
# ----------------------------------------------------

# %% [markdown]
# # PyTorch Imports

# %%
pwd
# Out:
# '/kaggle/working'

# %%
import torch
import torchvision
import torch.nn as nn
import albumentations as A
import torch.optim as optim
from torchvision import models
import torch.nn.functional as F
from torch.optim import lr_scheduler
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from albumentations.pytorch import ToTensorV2
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# # PyTorch Configuration

# %%
class CFG:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    split_pct = 0.2
    learning_rate = 3e-4
    batch_size = 4
    epochs = 3

# %%
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

# %%
CFG.device
# Out:
# device(type='cpu')

# %% [markdown]
# # Working with data

# %% [markdown]
# ### Shuffling the data.

# %%
#permuted_train_img_lst = np.random.permutation(np.array(sorted_train_img_lst))
#permuted_train_mask_lst = [x.replace(".jpg", "_mask.gif") for x in permuted_train_img_lst]
permuted_train_img_lst=sorted_train_img_lst
permuted_train_mask_lst=sorted_train_mask_lst
print(permuted_train_img_lst[:5])
print(permuted_train_mask_lst[:5])
# Out:
# ['crack-o-1.jpg', 'crack-o-10.jpg', 'crack-o-100.jpg', 'crack-o-101.jpg', 'crack-o-102.jpg']
# ['crack-o-1.png', 'crack-o-10.png', 'crack-o-100.png', 'crack-o-101.png', 'crack-o-102.png']

# %%
show_images(permuted_train_img_lst,permuted_train_mask_lst)
# Out:
# ../input/concrete-crack-images/images/crack-o-1.jpg
# (256, 256)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# ../input/concrete-crack-images/masks/crack-o-1.png
# (256, 256)
# ----------------------------------------------------
# ../input/concrete-crack-images/images/crack-o-10.jpg
# (256, 256)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# ../input/concrete-crack-images/masks/crack-o-10.png
# (256, 256)
# ----------------------------------------------------

# %% [markdown]
# ### Splitting into Training and Validation

# %%
length = len(permuted_train_img_lst)
print(length*0.2) # convert this to int
# Out:
# 160.0

# %%
train_images_list = permuted_train_img_lst[int(CFG.split_pct*len(permuted_train_img_lst)) :]
train_masks_list = permuted_train_mask_lst[int(CFG.split_pct*len(permuted_train_mask_lst)) :]
print(len(train_masks_list))

val_images_list = permuted_train_img_lst[: int(CFG.split_pct*len(permuted_train_img_lst))]
val_masks_list = permuted_train_mask_lst[: int(CFG.split_pct*len(permuted_train_mask_lst))]
print(len(val_masks_list))

# 4071+1017=5088 (split includes all items)
# Out:
# 640
# 160

# %% [markdown]
# ### Visualizing Train Dataset

# %%
show_images(train_images_list,train_masks_list)
# Out:
# ../input/concrete-crack-images/images/crack-o-243.jpg
# (256, 256)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# ../input/concrete-crack-images/masks/crack-o-243.png
# (256, 256)
# ----------------------------------------------------
# ../input/concrete-crack-images/images/crack-o-244.jpg
# (256, 256)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# ../input/concrete-crack-images/masks/crack-o-244.png
# (256, 256)
# ----------------------------------------------------

# %% [markdown]
# ### Visualizing Validation Dataset

# %%
show_images(val_images_list,val_masks_list)
# Out:
# ../input/concrete-crack-images/images/crack-o-1.jpg
# (256, 256)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# ../input/concrete-crack-images/masks/crack-o-1.png
# (256, 256)
# ----------------------------------------------------
# ../input/concrete-crack-images/images/crack-o-10.jpg
# (256, 256)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# ../input/concrete-crack-images/masks/crack-o-10.png
# (256, 256)
# ----------------------------------------------------

# %% [markdown]
# # Dataset Class

# %%
class CarvanaDataset(Dataset):
    def __init__(self,img_list,mask_list,transform=None):
        self.img_list = img_list
        self.mask_list = mask_list
        self.transform = transform

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self,index):
        img_path = os.path.join(ROOTDIR.train,self.img_list[index])
        mask_path = os.path.join(ROOTDIR.train_mask,self.mask_list[index])
        img = Image.open(img_path)
        mask = Image.open(mask_path)
        img = np.array(img)
        mask = np.array(mask)
        mask[mask==255.0] = 1.0
        #img_mask_dict = {"image": img, "mask": mask}

        if self.transform:
            augmentation = self.transform(image=img, mask=mask)
            img = augmentation["image"]
            mask = augmentation["mask"]
            mask = torch.unsqueeze(mask,0)
            #transformations = self.transform(image=img, mask=mask)
            #img = transformations["image"]
            #mask = transformations["mask"]

        return img,mask

# %%
train_transform = A.Compose([A.Resize(572,572),
                             A.Rotate(limit=15,p=0.1),
                             A.HorizontalFlip(p=0.5),
                             A.Normalize(mean=(0,0,0),std=(1,1,1),max_pixel_value=255),
                             ToTensorV2()])

val_transform = A.Compose([A.Resize(572,572),
                           A.Normalize(mean=(0,0,0),std=(1,1,1),max_pixel_value=255),
                           ToTensorV2()])

# %%
train_dataset = CarvanaDataset(train_images_list, train_masks_list, transform = train_transform)
val_dataset = CarvanaDataset(val_images_list, val_masks_list, transform = train_transform)

# %%
idx = 200
img,mask = train_dataset[idx]

# %%
mask.shape
# Out:
# torch.Size([1, 572, 572])

# %%
img.max()
# Out:
# tensor(0.8549)

# %%
def show_single_img(img,mask,index=None,train=True):
    if index:
        if train:
            img,mask = train_dataset[index]
        else:
            img,mask = val_dataset[index]
    plt.imshow(img.permute(1,2,0),cmap="gray")  # Convert (3, 572, 572) -> (572, 572, 3)
    plt.show()
    plt.imshow(mask.permute(1,2,0), cmap="gray")  # Convert (1, 572, 572) -> (572, 572, 1)
    print(mask.shape)
    plt.show()

# %%
print("---------------Train---------------")
show_single_img(img,mask,index=15,train=False)
print("---------------Validation---------------")
show_single_img(img,mask,index=15,train=True)
# Out:
# ---------------Train---------------
# torch.Size([1, 572, 572])
# ---------------Validation---------------
# torch.Size([1, 572, 572])

# %% [markdown]
# # Dataloader

# %%
train_dataloader = DataLoader(train_dataset,batch_size=CFG.batch_size,shuffle=True)
val_dataloader = DataLoader(val_dataset,batch_size=CFG.batch_size,shuffle=False)

# %%
a = iter(train_dataloader)
img,mask = a.next()
print(img.shape,mask.shape)
# Out:
# torch.Size([4, 3, 572, 572]) torch.Size([4, 1, 572, 572])

# %% [markdown]
# ### Utility Functions

# %%
def double_conv(in_ch, out_ch):
    conv = nn.Sequential(
        nn.Conv2d(in_channels=in_ch,out_channels=out_ch,kernel_size=3,stride=1,padding=1),
        nn.BatchNorm2d(out_ch),
        nn.ReLU(inplace=True),
        nn.Conv2d(in_channels=out_ch,out_channels=out_ch,kernel_size=3,stride=1,padding=1),
        nn.BatchNorm2d(out_ch),
        nn.ReLU(inplace=True)
    )

    return conv

#def cropper(og_tensor, target_tensor):
#    og_shape = og_tensor.shape[2]
#    target_shape = target_tensor.shape[2]
#    delta = (og_shape - target_shape) // 2
#    cropped_og_tensor = og_tensor[:,:,delta:og_shape-delta,delta:og_shape-delta]
#    return cropped_og_tensor


def padder(left_tensor, right_tensor):
    # left_tensor is the tensor on the encoder side of UNET
    # right_tensor is the tensor on the decoder side  of the UNET

    if left_tensor.shape != right_tensor.shape:
        padded = torch.zeros(left_tensor.shape)
        padded[:, :, :right_tensor.shape[2], :right_tensor.shape[3]] = right_tensor
        return padded.to(CFG.device)

    return right_tensor.to(CFG.device)

# %% [markdown]
# # UNET MODEL FROM SCRATCH

# %%
class UNET(nn.Module):
    def __init__(self,in_chnls, n_classes):
        super(UNET,self).__init__()

        self.in_chnls = in_chnls
        self.n_classes = n_classes

        self.max_pool = nn.MaxPool2d(kernel_size=2,stride=2)

        self.down_conv_1 = double_conv(in_ch=self.in_chnls,out_ch=64)
        self.down_conv_2 = double_conv(in_ch=64,out_ch=128)
        self.down_conv_3 = double_conv(in_ch=128,out_ch=256)
        self.down_conv_4 = double_conv(in_ch=256,out_ch=512)
        self.down_conv_5 = double_conv(in_ch=512,out_ch=1024)
        #print(self.down_conv_1)

        self.up_conv_trans_1 = nn.ConvTranspose2d(in_channels=1024,out_channels=512,kernel_size=2,stride=2)
        self.up_conv_trans_2 = nn.ConvTranspose2d(in_channels=512,out_channels=256,kernel_size=2,stride=2)
        self.up_conv_trans_3 = nn.ConvTranspose2d(in_channels=256,out_channels=128,kernel_size=2,stride=2)
        self.up_conv_trans_4 = nn.ConvTranspose2d(in_channels=128,out_channels=64,kernel_size=2,stride=2)

        self.up_conv_1 = double_conv(in_ch=1024,out_ch=512)
        self.up_conv_2 = double_conv(in_ch=512,out_ch=256)
        self.up_conv_3 = double_conv(in_ch=256,out_ch=128)
        self.up_conv_4 = double_conv(in_ch=128,out_ch=64)

        self.conv_1x1 = nn.Conv2d(in_channels=64,out_channels=self.n_classes,kernel_size=1,stride=1)

    def forward(self,x):

        # encoding
        x1 = self.down_conv_1(x)
        #print("X1", x1.shape)
        p1 = self.max_pool(x1)
        #print("p1", p1.shape)
        x2 = self.down_conv_2(p1)
        #print("X2", x2.shape)
        p2 = self.max_pool(x2)
        #print("p2", p2.shape)
        x3 = self.down_conv_3(p2)
        #print("X2", x3.shape)
        p3 = self.max_pool(x3)
        #print("p3", p3.shape)
        x4 = self.down_conv_4(p3)
        #print("X4", x4.shape)
        p4 = self.max_pool(x4)
        #print("p4", p4.shape)
        x5 = self.down_conv_5(p4)
        #print("X5", x5.shape)

        # decoding
        d1 = self.up_conv_trans_1(x5)  # up transpose convolution ("up sampling" as called in UNET paper)
        pad1 = padder(x4,d1) # padding d1 to match x4 shape
        cat1 = torch.cat([x4,pad1],dim=1) # concatenating padded d1 and x4 on channel dimension(dim 1) [batch(dim 0),channel(dim 1),height(dim 2),width(dim 3)]
        uc1 = self.up_conv_1(cat1) # 1st up double convolution

        d2 = self.up_conv_trans_2(uc1)
        pad2 = padder(x3,d2)
        cat2 = torch.cat([x3,pad2],dim=1)
        uc2 = self.up_conv_2(cat2)

        d3 = self.up_conv_trans_3(uc2)
        pad3 = padder(x2,d3)
        cat3 = torch.cat([x2,pad3],dim=1)
        uc3 = self.up_conv_3(cat3)

        d4 = self.up_conv_trans_4(uc3)
        pad4 = padder(x1,d4)
        cat4 = torch.cat([x1,pad4],dim=1)
        uc4 = self.up_conv_4(cat4)

        conv_1x1 = self.conv_1x1(uc4)
        return conv_1x1
        #print(conv_1x1.shape)

# %% [markdown]
# # Training and Validation

# %% [markdown]
# ### Train Function

# %%
def train_model(model,dataloader,criterion,optimizer):
    model.train()
    train_running_loss = 0.0
    for j,img_mask in enumerate(tqdm(dataloader)):
        img = img_mask[0].float().to(CFG.device)
        #print(" ----- IMAGE -----")
        #print(img)
        mask = img_mask[1].float().to(CFG.device)
        #print(" ----- MASK -----")
        #print(mask)

        y_pred = model(img)
        #print(" ----- Y PRED -----")
        #print(y_pred)
        #print(" ----- Y PRED SHAPE -----")#
        #print(y_pred.shape)
        optimizer.zero_grad()

        loss = criterion(y_pred,mask)

        train_running_loss += loss.item() * CFG.batch_size

        loss.backward()
        optimizer.step()

    train_loss = train_running_loss / (j+1)
    return train_loss

# %% [markdown]
# ### Validation Function

# %%
def val_model(model,dataloader,criterion,optimizer):
    model.eval()
    val_running_loss = 0
    with torch.no_grad():
        for j,img_mask in enumerate(tqdm(dataloader)):
            img = img_mask[0].float().to(CFG.device)
            mask = img_mask[1].float().to(CFG.device)
            y_pred = model(img)
            loss = criterion(y_pred,mask)

            val_running_loss += loss.item() * CFG.batch_size

        val_loss = val_running_loss / (j+1)
    return val_loss

# %%
model = UNET(in_chnls = 3, n_classes = 1).to(CFG.device)
optimizer = optim.Adam(model.parameters(), lr = CFG.learning_rate)
criterion = nn.BCEWithLogitsLoss()
train_loss_lst = []
val_loss_lst = []

# %% [markdown]
# ### Train and Validation Loop

# %%
for i in tqdm(range(CFG.epochs)):
    train_loss = train_model(model=model,dataloader=train_dataloader,criterion=criterion,optimizer=optimizer)
    val_loss = val_model(model=model,dataloader=val_dataloader,criterion=criterion,optimizer=optimizer)
    train_loss_lst.append(train_loss)
    val_loss_lst.append(val_loss)
    print(f" Train Loss : {train_loss:.4f}")
    print(f" Validation Loss : {val_loss:.4f}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/160 [00:00<?, ?it/s]

# %% [markdown]
# ### Training and Validation Loss Plot

# %%
plt.plot(train_loss_lst, color="green", label='train loss')
plt.plot(val_loss_lst, color="red", label='validation loss')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.show()

# %% [markdown]
# # Saving Model

# %%
TRAINED_FILE = "./unet_scratch.pth"

# %%
torch.save(model.state_dict(), TRAINED_FILE)

# %%
from IPython.display import FileLink
FileLink(TRAINED_FILE)

# %% [markdown]
# # Testing

# %%
trained_model = UNET(in_chnls = 3, n_classes = 1)

# %%
UNET_TRAINED = "../input/unet-4-epoch-trained/unet_scratch.pth"

# %%
trained_model.load_state_dict(torch.load(UNET_TRAINED))

# %%
trained_model = trained_model.to("cuda")
trained_model.eval()

# %%
img_path = "../input/carvana-image-masking-challenge/29bb3ece3180_11.jpg"

img = cv2.imread(img_path)

# %%
plt.imshow(img)
plt.show()

# %%
test_transform = A.Compose([A.Resize(572,572),
                           A.Normalize(mean=(0,0,0),std=(1,1,1),max_pixel_value=255),
                           ToTensorV2()])

# %%
test_image = test_transform(image = img)

print(test_image)

print(test_image["image"].dtype)
print(test_image["image"].shape)

img = test_image["image"].unsqueeze(0)
print(img.shape)

img = img.to("cuda")

# %%
pred = trained_model(img)
pred.shape

# %%
mask = pred.squeeze(0).cpu().detach().numpy()
print(mask.shape)
mask = mask.transpose(1,2,0)
print(mask.shape)

# %%
display_test_img = test_image["image"].cpu().detach().numpy()
print(display_test_img.shape)
display_test_img = display_test_img.transpose(1,2,0)
display_test_img.shape

# %%
mask[mask < 0]=0
mask[mask > 0]=1

# %%
print("-------Original Image-------")
plt.imshow(display_test_img, cmap="gray")
plt.show()
print("-------Image Mask-------")
plt.imshow(mask,cmap="gray")
plt.show()
